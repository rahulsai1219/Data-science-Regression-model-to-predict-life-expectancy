# %%
import pandas as pd

# %% [markdown]
# # Reading the given csv file

# %%
data=pd.read_csv('Downloads/Life Expectancy Data.csv')

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Describing the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %%
data.isna().mean()
# Out:
# Country                            0.000000
# Year                               0.000000
# Status                             0.000000
# Life expectancy                    0.003404
# Adult Mortality                    0.003404
# infant deaths                      0.000000
# Alcohol                            0.066031
# percentage expenditure             0.000000
# Hepatitis B                        0.188223
# Measles                            0.000000
#  BMI                               0.011572
# under-five deaths                  0.000000
# Polio                              0.006467
# Total expenditure                  0.076923
# Diphtheria                         0.006467
#  HIV/AIDS                          0.000000
# GDP                                0.152485
# Population                         0.221920
#  thinness  1-19 years              0.011572
#  thinness 5-9 years                0.011572
# Income composition of resources    0.056841
# ...

# %%
data.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
clean_data=data.dropna()

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            1649 non-null object
# Year                               1649 non-null int64
# Status                             1649 non-null object
# Life expectancy                    1649 non-null float64
# Adult Mortality                    1649 non-null float64
# infant deaths                      1649 non-null int64
# Alcohol                            1649 non-null float64
# percentage expenditure             1649 non-null float64
# Hepatitis B                        1649 non-null float64
# Measles                            1649 non-null int64
#  BMI                               1649 non-null float64
# under-five deaths                  1649 non-null int64
# Polio                              1649 non-null float64
# Total expenditure                  1649 non-null float64
# Diphtheria                         1649 non-null float64
# ...

# %% [markdown]
# ## After removing all NaN values, data is reduced to 1649 rows from 2938 rows. This might cause distortion!

# %% [markdown]
# ## Dropping these columns as they are categorical and has nothing to do with Life Expectancy

# %%
cleaned_dataset=data.drop(['Country','Year','Status','percentage expenditure'],axis=1)

# %% [markdown]
# #percentage expecditure and Total expenditure are duplicating and representing similar information and similar impact on life Expectancy

# %%
cleaned_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 18 columns):
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
#  HIV/AIDS                          2938 non-null float64
# GDP                                2490 non-null float64
# Population                         2286 non-null float64
#  thinness  1-19 years              2904 non-null float64
# ...

# %% [markdown]
# ### Standardizing column names

# %%
cleaned_dataset.columns= cleaned_dataset.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(', '').str.replace(')', '')

# %%
cleaned_dataset.head()
# Out:
#    life_expectancy  adult_mortality  infant_deaths  alcohol  hepatitis_b  \
# 0             65.0            263.0             62     0.01         65.0
# 1             59.9            271.0             64     0.01         62.0
# 2             59.9            268.0             66     0.01         64.0
# 3             59.5            272.0             69     0.01         67.0
# 4             59.2            275.0             71     0.01         68.0
#
#    measles   bmi  under-five_deaths  polio  total_expenditure  diphtheria  \
# 0     1154  19.1                 83    6.0               8.16        65.0
# 1      492  18.6                 86   58.0               8.18        62.0
# 2      430  18.1                 89   62.0               8.13        64.0
# 3     2787  17.6                 93   67.0               8.52        67.0
# 4     3013  17.2                 97   68.0               7.87        68.0
#
#    hiv/aids         gdp  population  thinness__1-19_years  thinness_5-9_years  \
# ...

# %% [markdown]
# ### Checking for outliers before handling missing values

# %%
cleaned_dataset.boxplot(figsize=(35,25))

# %% [markdown]
# ## According to above observation population column has outliers and NaN should be handelled with median values

# %% [markdown]
# ## Handling missing values

# %%
mean_life=cleaned_dataset.life_expectancy.mean()
mean_life
# Out:
# 69.22493169398912

# %%
cleaned_dataset['life_expectancy']=cleaned_dataset['life_expectancy'].fillna(mean_life)
cleaned_dataset['life_expectancy']
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: life_expectancy, Length: 2938, dtype: float64

# %%
cleaned_dataset.life_expectancy.isna().mean()
# Out:
# 0.0

# %%
cleaned_dataset.adult_mortality.isna().mean()
# Out:
# 0.0034036759700476512

# %%
cleaned_dataset['adult_mortality']=cleaned_dataset['adult_mortality'].fillna(cleaned_dataset.adult_mortality.mean())
cleaned_dataset['adult_mortality']
# Out:
# 0       263.0
# 1       271.0
# 2       268.0
# 3       272.0
# 4       275.0
#         ...
# 2933    723.0
# 2934    715.0
# 2935     73.0
# 2936    686.0
# 2937    665.0
# Name: adult_mortality, Length: 2938, dtype: float64

# %%
cleaned_dataset.adult_mortality.isna().mean()
# Out:
# 0.0

# %%
cleaned_dataset.infant_deaths=cleaned_dataset.infant_deaths.fillna(cleaned_dataset.infant_deaths.mean())
cleaned_dataset.infant_deaths
# Out:
# 0       62
# 1       64
# 2       66
# 3       69
# 4       71
#         ..
# 2933    27
# 2934    26
# 2935    25
# 2936    25
# 2937    24
# Name: infant_deaths, Length: 2938, dtype: int64

# %%
cleaned_dataset.alcohol=cleaned_dataset.alcohol.fillna(cleaned_dataset.alcohol.mean())
cleaned_dataset.alcohol
# Out:
# 0       0.01
# 1       0.01
# 2       0.01
# 3       0.01
# 4       0.01
#         ...
# 2933    4.36
# 2934    4.06
# 2935    4.43
# 2936    1.72
# 2937    1.68
# Name: alcohol, Length: 2938, dtype: float64

# %%
cleaned_dataset.hepatitis_b=cleaned_dataset.hepatitis_b.fillna(cleaned_dataset.hepatitis_b.mean())

# %%
cleaned_dataset.measles=cleaned_dataset.measles.fillna(cleaned_dataset.measles.mean())

# %%
cleaned_dataset.bmi=cleaned_dataset.bmi.fillna(cleaned_dataset.bmi.mean())

# %%
cleaned_dataset.columns= cleaned_dataset.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(', '').str.replace(')', '').str.replace('-', '_').str.replace('/','_')

# %%
cleaned_dataset.under_five_deaths=cleaned_dataset.under_five_deaths.fillna(cleaned_dataset.under_five_deaths.mean())

# %%
cleaned_dataset.polio=cleaned_dataset.polio.fillna(cleaned_dataset.polio.mean())

# %%
cleaned_dataset.total_expenditure=cleaned_dataset.total_expenditure.fillna(cleaned_dataset.total_expenditure.mean())

# %%
cleaned_dataset.diphtheria=cleaned_dataset.diphtheria.fillna(cleaned_dataset.diphtheria.mean())

# %%
cleaned_dataset.hiv_aids=cleaned_dataset.hiv_aids.fillna(cleaned_dataset.hiv_aids.mean())

# %%
cleaned_dataset.gdp=cleaned_dataset.gdp.fillna(cleaned_dataset.gdp.mean())

# %%
#Replacing Nan with median vlaues to avoid data distortion due to outliers
cleaned_dataset.population=cleaned_dataset.population.fillna(cleaned_dataset.population.median())

# %%
cleaned_dataset.thinness__1_19_years=cleaned_dataset.thinness__1_19_years.fillna(cleaned_dataset.thinness__1_19_years.mean())

# %%
cleaned_dataset.thinness_5_9_years=cleaned_dataset.thinness_5_9_years.fillna(cleaned_dataset.thinness_5_9_years.mean())

# %%
cleaned_dataset.income_composition_of_resources=cleaned_dataset.income_composition_of_resources.fillna(cleaned_dataset.income_composition_of_resources.mean())

# %%
cleaned_dataset.schooling=cleaned_dataset.schooling.fillna(cleaned_dataset.schooling.mean())

# %%
cleaned_dataset
# Out:
#       life_expectancy  adult_mortality  infant_deaths  alcohol  hepatitis_b  \
# 0                65.0            263.0             62     0.01         65.0
# 1                59.9            271.0             64     0.01         62.0
# 2                59.9            268.0             66     0.01         64.0
# 3                59.5            272.0             69     0.01         67.0
# 4                59.2            275.0             71     0.01         68.0
# ...               ...              ...            ...      ...          ...
# 2933             44.3            723.0             27     4.36         68.0
# 2934             44.5            715.0             26     4.06          7.0
# 2935             44.8             73.0             25     4.43         73.0
# 2936             45.3            686.0             25     1.72         76.0
# 2937             46.0            665.0             24     1.68         79.0
#
# ...

# %%
full_data=cleaned_dataset
full_data.head(10)
# Out:
#    life_expectancy  adult_mortality  infant_deaths  alcohol  hepatitis_b  \
# 0             65.0            263.0             62     0.01         65.0
# 1             59.9            271.0             64     0.01         62.0
# 2             59.9            268.0             66     0.01         64.0
# 3             59.5            272.0             69     0.01         67.0
# 4             59.2            275.0             71     0.01         68.0
# 5             58.8            279.0             74     0.01         66.0
# 6             58.6            281.0             77     0.01         63.0
# 7             58.1            287.0             80     0.03         64.0
# 8             57.5            295.0             82     0.02         63.0
# 9             57.3            295.0             84     0.03         64.0
#
#    measles   bmi  under_five_deaths  polio  total_expenditure  diphtheria  \
# 0     1154  19.1                 83    6.0               8.16        65.0
# ...

# %%
full_data.columns
# Out:
# Index(['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
#        'hepatitis_b', 'measles', 'bmi', 'under_five_deaths', 'polio',
#        'total_expenditure', 'diphtheria', 'hiv_aids', 'gdp', 'population',
#        'thinness__1_19_years', 'thinness_5_9_years',
#        'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
upper_lim=full_data[['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
       'hepatitis_b', 'measles', 'bmi', 'under_five_deaths', 'polio',
       'total_expenditure', 'diphtheria', 'hiv_aids', 'gdp', 'population',
       'thinness__1_19_years', 'thinness_5_9_years',
       'income_composition_of_resources', 'schooling']].quantile(.95)
upper_lim
# Out:
# life_expectancy                    8.200000e+01
# adult_mortality                    3.973000e+02
# infant_deaths                      9.415000e+01
# alcohol                            1.189000e+01
# hepatitis_b                        9.900000e+01
# measles                            9.985550e+03
# bmi                                6.470000e+01
# under_five_deaths                  1.380000e+02
# polio                              9.900000e+01
# total_expenditure                  9.691500e+00
# diphtheria                         9.900000e+01
# hiv_aids                           8.515000e+00
# gdp                                3.769023e+04
# population                         4.125504e+07
# thinness__1_19_years               1.380000e+01
# thinness_5_9_years                 1.380000e+01
# income_composition_of_resources    8.900000e-01
# schooling                          1.680000e+01
# Name: 0.95, dtype: float64

# %%
lower_lim=full_data[['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
       'hepatitis_b', 'measles', 'bmi', 'under_five_deaths', 'polio',
       'total_expenditure', 'diphtheria', 'hiv_aids', 'gdp', 'population',
       'thinness__1_19_years', 'thinness_5_9_years',
       'income_composition_of_resources', 'schooling']].quantile(.05)
lower_lim
# Out:
# life_expectancy                       51.400000
# adult_mortality                       13.000000
# infant_deaths                          0.000000
# alcohol                                0.010000
# hepatitis_b                            9.000000
# measles                                0.000000
# bmi                                    5.200000
# under_five_deaths                      0.000000
# polio                                  9.000000
# total_expenditure                      1.988500
# diphtheria                             9.000000
# hiv_aids                               0.100000
# gdp                                   81.834917
# population                         14644.150000
# thinness__1_19_years                   0.600000
# thinness_5_9_years                     0.500000
# income_composition_of_resources        0.291000
# schooling                              5.900000
# Name: 0.05, dtype: float64

# %%
new=(full_data[['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
       'hepatitis_b', 'measles', 'bmi', 'under_five_deaths', 'polio',
       'total_expenditure', 'diphtheria', 'hiv_aids', 'gdp', 'population',
       'thinness__1_19_years', 'thinness_5_9_years',
       'income_composition_of_resources', 'schooling']]<upper_lim) & (full_data[['life_expectancy', 'adult_mortality', 'infant_deaths', 'alcohol',
       'hepatitis_b', 'measles', 'bmi', 'under_five_deaths', 'polio',
       'total_expenditure', 'diphtheria', 'hiv_aids', 'gdp', 'population',
       'thinness__1_19_years', 'thinness_5_9_years',
       'income_composition_of_resources', 'schooling']]>lower_lim)

# %%
new
# Out:
#       life_expectancy  adult_mortality  infant_deaths  alcohol  hepatitis_b  \
# 0                True             True           True    False         True
# 1                True             True           True    False         True
# 2                True             True           True    False         True
# 3                True             True           True    False         True
# 4                True             True           True    False         True
# ...               ...              ...            ...      ...          ...
# 2933            False            False           True     True         True
# 2934            False            False           True     True        False
# 2935            False             True           True     True         True
# 2936            False            False           True     True         True
# 2937            False            False           True     True         True
#
# ...

# %%
new.boxplot(figsize=(35,25))

# %% [markdown]
# Question .1

# %%
full_data.corr()
# Out:
#                                  life_expectancy  adult_mortality  \
# life_expectancy                         1.000000        -0.696359
# adult_mortality                        -0.696359         1.000000
# infant_deaths                          -0.196535         0.078747
# alcohol                                 0.391598        -0.190408
# hepatitis_b                             0.203771        -0.138591
# measles                                -0.157574         0.031174
# bmi                                     0.559255        -0.381449
# under_five_deaths                      -0.222503         0.094135
# polio                                   0.461574        -0.272694
# total_expenditure                       0.207981        -0.110875
# diphtheria                              0.475418        -0.273014
# hiv_aids                               -0.556457         0.523727
# gdp                                     0.430493        -0.277053
# ...

# %% [markdown]
# ### From the above observation it can be incurred that schooling, income_composition_of_resourses and adult_morality are highly co-related with target variable life_expectancy

# %%
import seaborn as sns

# %matplotlib inline

# %%
sns.pairplot(full_data, x_vars=['adult_mortality', 'infant_deaths', 'alcohol',
       'hepatitis_b', 'measles', 'bmi', 'under_five_deaths', 'polio',
       'total_expenditure', 'diphtheria', 'hiv_aids', 'gdp', 'population',
       'thinness__1_19_years', 'thinness_5_9_years',
       'income_composition_of_resources','schooling'], y_vars='life_expectancy', height=5, aspect=1, kind='reg')

# %% [markdown]
# From the above plot it can be observed that 'adult_mortality','income_composition_of_resources','schooling' are highly contributing towards life expectancy.

# %%
sns.pairplot(full_data, x_vars=['adult_mortality','income_composition_of_resources','schooling'], y_vars='life_expectancy', height=5, aspect=1, kind='reg')

# %%
x=full_data[['adult_mortality','income_composition_of_resources','schooling']]
x
# Out:
#       adult_mortality  income_composition_of_resources  schooling
# 0               263.0                            0.479       10.1
# 1               271.0                            0.476       10.0
# 2               268.0                            0.470        9.9
# 3               272.0                            0.463        9.8
# 4               275.0                            0.454        9.5
# ...               ...                              ...        ...
# 2933            723.0                            0.407        9.2
# 2934            715.0                            0.418        9.5
# 2935             73.0                            0.427       10.0
# 2936            686.0                            0.427        9.8
# 2937            665.0                            0.434        9.8
#
# [2938 rows x 3 columns]

# %%
y=full_data[['life_expectancy']]
y
# Out:
#       life_expectancy
# 0                65.0
# 1                59.9
# 2                59.9
# 3                59.5
# 4                59.2
# ...               ...
# 2933             44.3
# 2934             44.5
# 2935             44.8
# 2936             45.3
# 2937             46.0
#
# [2938 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=1)

# %%
x_train.shape
x_train
# Out:
#       adult_mortality  income_composition_of_resources  schooling
# 452             122.0                         0.632000  13.100000
# 2295            187.0                         0.714000  12.200000
# 196              14.0                         0.545000   9.400000
# 2857             18.0                         0.000000   9.600000
# 1648             79.0                         0.783000  13.700000
# ...               ...                              ...        ...
# 2763             71.0                         0.627551  11.992793
# 905              26.0                         0.700000  14.300000
# 1096            288.0                         0.401000   8.900000
# 235             247.0                         0.703000  14.100000
# 1061            189.0                         0.616000  10.600000
#
# [2203 rows x 3 columns]

# %%
y_train.shape
y_train
# Out:
#       life_expectancy
# 452              72.6
# 2295             72.0
# 196              73.0
# 2857             69.0
# 1648             77.8
# ...               ...
# 2763             81.0
# 905              68.7
# 1096             56.3
# 235              68.2
# 1061             71.3
#
# [2203 rows x 1 columns]

# %%
x_test.shape
x_test
# Out:
#       adult_mortality  income_composition_of_resources  schooling
# 1268             61.0                            0.891       15.9
# 2719            362.0                            0.473       10.9
# 2710            229.0                            0.000       10.2
# 2028            218.0                            0.662       11.4
# 351             647.0                            0.559       11.7
# ...               ...                              ...        ...
# 2671             12.0                            0.706       14.4
# 1959            118.0                            0.785       13.0
# 1296             75.0                            0.828       14.9
# 816             177.0                            0.612       11.1
# 1216            188.0                            0.604       10.6
#
# [735 rows x 3 columns]

# %%
y_test.shape
y_test
# Out:
#       life_expectancy
# 1268             82.1
# 2719             58.4
# 2710             63.3
# 2028             67.9
# 351              47.8
# ...               ...
# 2671             74.7
# 1959             77.8
# 1296             79.8
# 816              68.6
# 1216             66.5
#
# [735 rows x 1 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF"]=[variance_inflation_factor(x_train.values,i) for i in range(x_train.shape[1])]
vif["Features"]=x_train.columns

# %%
vif
# Out:
#          VIF                         Features
# 0   1.947852                  adult_mortality
# 1  28.029894  income_composition_of_resources
# 2  29.820427                        schooling

# %% [markdown]
# ### From the above VFI values it can be incurred that income_composition_of_resources and schooling have VFI value more than 10 as these independent variables are corelating with each other

# %% [markdown]
# Hence removing one of these two to have VFI value less than 10

# %%
x=full_data[['adult_mortality','income_composition_of_resources']]
y=full_data[['life_expectancy']]
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=1)

vif=pd.DataFrame()
vif["VIF"]=[variance_inflation_factor(x_train.values,i) for i in range(x_train.shape[1])]
vif["Features"]=x_train.columns
vif
# Out:
#         VIF                         Features
# 0  1.817662                  adult_mortality
# 1  1.817662  income_composition_of_resources

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg=LinearRegression()

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(linreg.intercept_)
# Out:
# [61.16550129]

# %%
print(linreg.coef_)
# Out:
# [[-0.03688492 22.45944534]]

# %%
y_pred= linreg.predict(x_test)

# %%
y_pred
# Out:
# array([[79.65395988],
#        [57.09100267],
#        [61.18842047],
#        [68.51902561],
#        [40.55172687],
#        [81.72639252],
#        [66.40918513],
#        [73.71711936],
#        [64.53559778],
#        [76.01179859],
#        [74.06587154],
#        [82.74577694],
#        [54.57363103],
#        [58.84925479],
#        [77.00040653],
#        [63.33095711],
#        [76.70499649],
#        [70.07943945],
#        [62.83284584],
#        [50.49304684],
#        [70.61396845],
#        [71.7380295 ],
#        [68.92966385],
#        [58.52809771],
#        [72.45404514],
#        [79.53914966],
#        [78.31423641],
#        [68.20364525],
#        [71.660772  ],
#        [60.7884489 ],
#        [69.15106445],
#        [55.07122642],
#        [76.3577163 ],
#        [73.38760879],
#        [78.3830458 ],
#        [74.8116935 ],
#        [72.49150621],
#        [81.16657895],
#        [73.73776383],
#        [71.79465679],
#        [69.53120556],
# ...

# %%
y_test
# Out:
#       life_expectancy
# 1268             82.1
# 2719             58.4
# 2710             63.3
# 2028             67.9
# 351              47.8
# ...               ...
# 2671             74.7
# 1959             77.8
# 1296             79.8
# 816              68.6
# 1216             66.5
#
# [735 rows x 1 columns]

# %%
from sklearn import metrics
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 5.311456334986628

# %% [markdown]
# Question .2

# %%
q2=full_data[full_data['life_expectancy']<=65]
q2.corr()
# Out:
#                                  life_expectancy  adult_mortality  \
# life_expectancy                         1.000000        -0.379150
# adult_mortality                        -0.379150         1.000000
# infant_deaths                           0.020369        -0.073093
# alcohol                                -0.164379         0.135435
# hepatitis_b                            -0.025855         0.030471
# measles                                -0.111805        -0.082307
# bmi                                     0.261279         0.031789
# under_five_deaths                      -0.008521        -0.070711
# polio                                   0.157013         0.072164
# total_expenditure                      -0.146293         0.118355
# diphtheria                              0.208416         0.089132
# hiv_aids                               -0.542634         0.400252
# gdp                                     0.053972         0.084177
# ...

# %% [markdown]
# Question .7

# %%
q7=data.sort_values(by=['population'], ascending=False).head(50)
data.columns= data.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(', '').str.replace(')', '').str.replace('-', '_').str.replace('/','_')
q8=data.sort_values(by=['life_expectancy'], ascending=True).head(50)
q7
# Out:
#                  country  year      status  life_expectancy  adult_mortality  \
# 1187               India  2014  Developing             68.0            184.0
# 1194               India  2007  Developing             65.2             26.0
# 1195               India  2006  Developing             64.8             28.0
# 1196               India  2005  Developing             64.4            211.0
# 1197               India  2004  Developing             64.0            214.0
# 1202           Indonesia  2015  Developing             69.1            176.0
# 1203           Indonesia  2014  Developing             68.9            179.0
# 1205           Indonesia  2012  Developing             68.5            183.0
# 1207           Indonesia  2010  Developing             68.1            187.0
# 1209           Indonesia  2008  Developing             67.7            189.0
# 1210           Indonesia  2007  Developing             67.5             19.0
# ...

# %% [markdown]
# # Answers to the questions in life_expectancy.docx

# %% [markdown]
# 1. According to the co-relation observed schooling, income_composition_of_resourses and adult_morality are highly affecting life_expectancy
#
# 2. Countries having lower life expectancy (<65) need not invest in healthcare expenditure as its not having much affect on life expectancy.
#
# 3. Adult mortality has very high impact on life expectancy, However infant deaths doesn't corelate much with life expectancy.
#
# 4. Eating habits, lifestyle, exercise and smoking are not given in the data set.
#
# 5. Among all the independant variables schooling has the highest impact on life expectancy.
#
# 6. On the whole data-set achohol has +ve co-relation value of 0.39 but considering countries having life spans under 65, Alcohol has -ve co-relation with life expectancy.
#
# 7. No, Densely populated countries like India, Indonesia and Brazil doesn't have low life expectancy.
#
# 8. Immunization coverage is not given in the data set.
